# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab

params = {'legend.fontsize': 'xx-large',
          'figure.figsize': (15, 10),
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
pylab.rcParams.update(params)

# %% [markdown]
# # Basic LSTM Model

# %% [markdown]
# ### Oil Price Data Processing

# %%
oil_price = pd.read_csv('DCOILWTICO.csv')
oil_price.head()
# Out:
#          DATE DCOILWTICO
# 0  2012-01-03     102.96
# 1  2012-01-04     103.22
# 2  2012-01-05     101.81
# 3  2012-01-06     101.56
# 4  2012-01-09     101.31

# %%
oil_price.shape
# Out:
# (2086, 2)

# %%
# Convert string to Datetime
oil_price['DATE'] = pd.to_datetime(oil_price['DATE'])

# %%
# Process the oil price data, there are some '.' data in it
oil_price.loc[oil_price['DCOILWTICO'] == '.','DCOILWTICO'] = np.nan

# Fill the None with the last day's price
oil_price = oil_price.fillna(method='pad')

# %%
# Set time as index
oil_price = oil_price.set_index('DATE')
oil_price
# Out:
#            DCOILWTICO
# DATE
# 2012-01-03     102.96
# 2012-01-04     103.22
# 2012-01-05     101.81
# 2012-01-06     101.56
# 2012-01-09     101.31
# ...               ...
# 2019-12-25      61.17
# 2019-12-26      61.72
# 2019-12-27      61.76
# 2019-12-30      61.66
# 2019-12-31      61.14
#
# [2086 rows x 1 columns]

# %% [markdown]
# ### Plot the oil price trend

# %%
# Convert the price data type to 'float'
oil_price['DCOILWTICO'] = oil_price['DCOILWTICO'].astype(float)
oil_price.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# ### Divide the dataset into train set and test set

# %%
train_size = int(len(oil_price) * 0.75)
test_size = len(oil_price) - train_size
train = oil_price.iloc[0:train_size]
test = oil_price.iloc[train_size: len(oil_price)]
display(len(train), len(test))
# Out:
# 1564
# 522

# %% [markdown]
# ### Normalisation of data

# %%
from sklearn.preprocessing import RobustScaler


dcoilwtico_transformer = RobustScaler()
train['DCOILWTICO'] = dcoilwtico_transformer.fit_transform(train[['DCOILWTICO']])
test['DCOILWTICO'] = dcoilwtico_transformer.fit_transform(test[['DCOILWTICO']])
# Out:
# C:\Users\Shiqi Wang\AppData\Local\Temp\ipykernel_11904\1978691906.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['DCOILWTICO'] = dcoilwtico_transformer.fit_transform(train[['DCOILWTICO']])
# C:\Users\Shiqi Wang\AppData\Local\Temp\ipykernel_11904\1978691906.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['DCOILWTICO'] = dcoilwtico_transformer.fit_transform(test[['DCOILWTICO']])

# %% [markdown]
# ### Construct the X_train, y_train, X_test, y_test with time_step=10

# %%
def create_dataset_LSTM(X, y, time_steps):
    Xs = []
    ys = []
    for i in range(len(X)-time_steps):
        Xs.append(X.iloc[i:(i+time_steps)].values)
        ys.append(y.iloc[i+time_steps])
    return np.array(Xs), np.array(ys)

# %%
time_steps = 30
X_train, y_train = create_dataset_LSTM(train, train.DCOILWTICO, time_steps)
X_test, y_test = create_dataset_LSTM(test, test.DCOILWTICO, time_steps)
print(X_train.shape, y_train.shape)
# Out:
# (1534, 30, 1) (1534,)

# %% [markdown]
# ### Build the LSTM model

# %%
from tensorflow import keras

model = keras.Sequential()
model.add(
    keras.layers.Bidirectional(
        keras.layers.LSTM(
            units=64, 
            input_shape=(X_train.shape[1], X_train.shape[2])
        )
    )
)

model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.Dense(units=1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %% [markdown]
# ### Training the model

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs=120, 
    batch_size=64, 
    validation_split=0.1, 
    shuffle=False
)
# Out:
# Epoch 1/120
# 22/22 [==============================] - 3s 34ms/step - loss: 0.1023 - val_loss: 0.0043
# Epoch 2/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0239 - val_loss: 0.0025
# Epoch 3/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0201 - val_loss: 0.0028
# Epoch 4/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0116 - val_loss: 0.0020
# Epoch 5/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0121 - val_loss: 0.0024
# Epoch 6/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0089 - val_loss: 0.0020
# Epoch 7/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0085 - val_loss: 0.0022
# Epoch 8/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0071 - val_loss: 0.0019
# Epoch 9/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0072 - val_loss: 0.0019
# Epoch 10/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0071 - val_loss: 0.0017
# Epoch 11/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0060 - val_loss: 0.0018
# Epoch 12/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0058 - val_loss: 0.0016
# Epoch 13/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0061 - val_loss: 0.0015
# Epoch 14/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0062 - val_loss: 0.0015
# Epoch 15/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0063 - val_loss: 0.0012
# Epoch 16/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0052 - val_loss: 0.0012
# Epoch 17/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 0.0012
# Epoch 18/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0059 - val_loss: 0.0011
# Epoch 19/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0055 - val_loss: 9.6859e-04
# Epoch 20/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0044 - val_loss: 0.0010
# Epoch 21/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 8.4890e-04
# Epoch 22/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0046 - val_loss: 9.5306e-04
# Epoch 23/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0045 - val_loss: 9.2441e-04
# Epoch 24/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0053 - val_loss: 8.2845e-04
# Epoch 25/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0043 - val_loss: 8.6020e-04
# Epoch 26/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0043 - val_loss: 8.2957e-04
# Epoch 27/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0042 - val_loss: 8.0173e-04
# Epoch 28/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 8.1719e-04
# Epoch 29/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0041 - val_loss: 8.1062e-04
# Epoch 30/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0042 - val_loss: 8.1032e-04
# Epoch 31/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 7.5646e-04
# Epoch 32/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0040 - val_loss: 7.7328e-04
# Epoch 33/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0041 - val_loss: 7.7402e-04
# Epoch 34/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0043 - val_loss: 8.7481e-04
# Epoch 35/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0049 - val_loss: 7.6540e-04
# Epoch 36/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0044 - val_loss: 7.4017e-04
# Epoch 37/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 7.1662e-04
# Epoch 38/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0040 - val_loss: 9.3982e-04
# Epoch 39/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0034 - val_loss: 7.5029e-04
# Epoch 40/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0041 - val_loss: 9.5077e-04
# Epoch 41/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0038 - val_loss: 7.7035e-04
# Epoch 42/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0049 - val_loss: 7.8537e-04
# Epoch 43/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0034 - val_loss: 7.1742e-04
# Epoch 44/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0042 - val_loss: 9.9128e-04
# Epoch 45/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0034 - val_loss: 7.5131e-04
# Epoch 46/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0050 - val_loss: 8.8446e-04
# Epoch 47/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0041 - val_loss: 7.5455e-04
# Epoch 48/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0046 - val_loss: 8.9989e-04
# Epoch 49/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0034 - val_loss: 9.6878e-04
# Epoch 50/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0042 - val_loss: 0.0012
# Epoch 51/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 7.7587e-04
# Epoch 52/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0047 - val_loss: 0.0013
# Epoch 53/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 8.3908e-04
# Epoch 54/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0062 - val_loss: 9.2509e-04
# Epoch 55/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 7.6340e-04
# Epoch 56/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0054 - val_loss: 8.0776e-04
# Epoch 57/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0032 - val_loss: 6.6698e-04
# Epoch 58/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0039 - val_loss: 8.2891e-04
# Epoch 59/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0031 - val_loss: 6.5995e-04
# Epoch 60/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0040 - val_loss: 8.2627e-04
# Epoch 61/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0034 - val_loss: 6.6379e-04
# Epoch 62/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0042 - val_loss: 7.4397e-04
# Epoch 63/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0032 - val_loss: 6.5476e-04
# Epoch 64/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0042 - val_loss: 7.3266e-04
# Epoch 65/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 6.6389e-04
# Epoch 66/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0044 - val_loss: 7.3204e-04
# Epoch 67/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 6.5789e-04
# Epoch 68/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0039 - val_loss: 7.7413e-04
# Epoch 69/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 6.3153e-04
# Epoch 70/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0038 - val_loss: 8.3720e-04
# Epoch 71/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 6.9217e-04
# Epoch 72/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0054 - val_loss: 7.0239e-04
# Epoch 73/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 6.4438e-04
# Epoch 74/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0043 - val_loss: 6.6039e-04
# Epoch 75/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 6.1676e-04
# Epoch 76/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 7.8469e-04
# Epoch 77/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 6.1221e-04
# Epoch 78/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 7.3855e-04
# Epoch 79/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0029 - val_loss: 6.0962e-04
# Epoch 80/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0040 - val_loss: 6.2665e-04
# Epoch 81/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0029 - val_loss: 5.5450e-04
# Epoch 82/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 6.1534e-04
# Epoch 83/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 5.5817e-04
# Epoch 84/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 6.9997e-04
# Epoch 85/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 6.3826e-04
# Epoch 86/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 7.4128e-04
# Epoch 87/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 6.2199e-04
# Epoch 88/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0044 - val_loss: 6.4131e-04
# Epoch 89/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0029 - val_loss: 5.8321e-04
# Epoch 90/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 6.9521e-04
# Epoch 91/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 6.3237e-04
# Epoch 92/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 7.4798e-04
# Epoch 93/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0027 - val_loss: 5.8714e-04
# Epoch 94/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 6.5628e-04
# Epoch 95/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0029 - val_loss: 5.7934e-04
# Epoch 96/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0044 - val_loss: 5.8176e-04
# Epoch 97/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 6.3184e-04
# Epoch 98/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0038 - val_loss: 5.8662e-04
# Epoch 99/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 5.0943e-04
# Epoch 100/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0031 - val_loss: 6.3871e-04
# Epoch 101/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0027 - val_loss: 5.1683e-04
# Epoch 102/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 6.1495e-04
# Epoch 103/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0027 - val_loss: 5.0425e-04
# Epoch 104/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0034 - val_loss: 5.3472e-04
# Epoch 105/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 4.8439e-04
# Epoch 106/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 6.6068e-04
# Epoch 107/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0025 - val_loss: 5.7090e-04
# Epoch 108/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0031 - val_loss: 7.3577e-04
# Epoch 109/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 5.0778e-04
# Epoch 110/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0029 - val_loss: 5.3801e-04
# Epoch 111/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0024 - val_loss: 5.0610e-04
# Epoch 112/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0032 - val_loss: 5.8355e-04
# Epoch 113/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0027 - val_loss: 4.9593e-04
# Epoch 114/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0034 - val_loss: 5.3537e-04
# Epoch 115/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 4.8223e-04
# Epoch 116/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 4.5601e-04
# Epoch 117/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0025 - val_loss: 4.3492e-04
# Epoch 118/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 5.3205e-04
# Epoch 119/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0025 - val_loss: 4.4341e-04
# Epoch 120/120
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0031 - val_loss: 4.8693e-04

# %%
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='validation_loss')
plt.legend()

# %% [markdown]
# ### Model Prediction

# %%
y_pred = model.predict(X_test)

# Inverse normalisation of data
y_test_inv = dcoilwtico_transformer.inverse_transform(y_test.reshape(1, -1))
y_pred_inv = dcoilwtico_transformer.inverse_transform(y_pred)
# Out:
# 16/16 [==============================] - 0s 3ms/step

# %% [markdown]
# ### Results Visualization

# %%
plt.plot(y_test_inv.flatten(), marker='.', label="true")
plt.plot(y_pred_inv.flatten(), 'r', label="prediction")
plt.ylabel('Crude Oil Price')
plt.xlabel('Time Step')
plt.legend()
plt.show()

# %%
MSE = np.sum((y_test_inv.flatten()-y_pred_inv.flatten()) ** 2)/y_test_inv.shape[1]
MSE
# Out:
# 2.511917299173983

# %% [markdown]
# # LSTM Model with Sentiment Score

# %% [markdown]
# ### Read News Headlines

# %%
news_head_df = pd.read_excel('Oil_News_Headlines.xlsx')
news_head_df.head()
# Out:
#                                                 text          date
# 0  Oil Dips as 2019 Ends; Big Gains on Year, Big ...  Dec 31, 2019
# 1  Oil falls but on track for biggest yearly rise...  Dec 31, 2019
# 2  Russian firms divert oil from Belarus as no 20...  Dec 31, 2019
# 3       Global stocks end 2019 close to record highs  Dec 31, 2019
# 4  Oil prices set for biggest yearly rise since 2...  Dec 30, 2019

# %% [markdown]
# ### Process the empty value

# %%
null_index = news_head_df.index[(news_head_df['date'] == ' ')]
news_head_df.drop(null_index, inplace=True)

# %% [markdown]
# ### Change the format of the date

# %%
news_head_df['date'] = pd.to_datetime(news_head_df['date'], format = '%b %d, %Y')
news_head_df.head()
# Out:
#                                                 text       date
# 0  Oil Dips as 2019 Ends; Big Gains on Year, Big ... 2019-12-31
# 1  Oil falls but on track for biggest yearly rise... 2019-12-31
# 2  Russian firms divert oil from Belarus as no 20... 2019-12-31
# 3       Global stocks end 2019 close to record highs 2019-12-31
# 4  Oil prices set for biggest yearly rise since 2... 2019-12-30

# %% [markdown]
# ### Calculate Sentiment Polarity

# %%
from textblob import TextBlob

# Calculate the sentiment score of a single headline
def get_sentiment(headline):
    blob = TextBlob(headline)
    return blob.sentiment.polarity

# Calculate the average sentiment score of the dataframe of a date
def get_average_sentiment(data_frame):
    score_list = []
    for index, values in data_frame.iterrows():
        polarity_score = get_sentiment(values['text'])
        score_list.append(polarity_score)
    return np.mean(score_list)

# %%
# Obtain the Series of date
date_series = news_head_df['date'].drop_duplicates()
date_series = date_series.reset_index(drop=True)
date_series
# Out:
# 0      2019-12-31
# 1      2019-12-30
# 2      2019-12-29
# 3      2019-12-27
# 4      2019-12-26
#           ...
# 2550   2012-01-06
# 2551   2012-01-05
# 2552   2012-01-04
# 2553   2012-01-03
# 2554   2012-01-01
# Name: date, Length: 2555, dtype: datetime64[ns]

# %%
polarity_score_list = []
# Iterate the date Series
for value in date_series.values:
    df_corresponding_date = news_head_df[news_head_df['date'] == value]
    polarity_score = get_average_sentiment(df_corresponding_date)
    polarity_score_list.append(polarity_score)

score_series = pd.Series(polarity_score_list)
score_series
# Out:
# 0       0.000000
# 1       0.019815
# 2       0.000000
# 3      -0.016667
# 4      -0.040000
#           ...
# 2550   -0.416667
# 2551   -0.091296
# 2552   -0.183125
# 2553   -0.341667
# 2554   -0.200000
# Length: 2555, dtype: float64

# %% [markdown]
# ### Construct the data frame with date and sentiment score

# %%
date_sentiment_df = pd.DataFrame({'DATE':date_series, 'SENTIMENT SCORE':score_series})
date_sentiment_df
# Out:
#            DATE  SENTIMENT SCORE
# 0    2019-12-31         0.000000
# 1    2019-12-30         0.019815
# 2    2019-12-29         0.000000
# 3    2019-12-27        -0.016667
# 4    2019-12-26        -0.040000
# ...         ...              ...
# 2550 2012-01-06        -0.416667
# 2551 2012-01-05        -0.091296
# 2552 2012-01-04        -0.183125
# 2553 2012-01-03        -0.341667
# 2554 2012-01-01        -0.200000
#
# [2555 rows x 2 columns]

# %% [markdown]
# ### Merge two date frames

# %%
oil_price_sentiment_df = pd.merge(oil_price, date_sentiment_df, on='DATE')
oil_price_sentiment_df = oil_price_sentiment_df.set_index('DATE')
oil_price_sentiment_df
# Out:
#             DCOILWTICO  SENTIMENT SCORE
# DATE
# 2012-01-03      102.96        -0.341667
# 2012-01-04      103.22        -0.183125
# 2012-01-05      101.81        -0.091296
# 2012-01-06      101.56        -0.416667
# 2012-01-09      101.31        -0.420000
# ...                ...              ...
# 2019-12-24       61.17        -0.035417
# 2019-12-26       61.72        -0.040000
# 2019-12-27       61.76        -0.016667
# 2019-12-30       61.66         0.019815
# 2019-12-31       61.14         0.000000
#
# [2069 rows x 2 columns]

# %% [markdown]
# ### Build train set and test set

# %%
senti_train_size = int(len(oil_price_sentiment_df) * 0.75)
senti_test_size = len(oil_price_sentiment_df) - senti_train_size
senti_train, senti_test = oil_price_sentiment_df.iloc[0:senti_train_size], oil_price_sentiment_df.iloc[senti_train_size:len(oil_price_sentiment_df)]
print(len(senti_train), len(senti_test))
# Out:
# 1551 518

# %% [markdown]
# ### Data Pre-processing

# %%
# senti_transformer = RobustScaler()
# senti_train['SENTIMENT SCORE'] = senti_transformer.fit_transform(senti_train[['SENTIMENT SCORE']])
# senti_test['SENTIMENT SCORE'] = senti_transformer.fit_transform(senti_test[['SENTIMENT SCORE']])

dcoi_transformer = RobustScaler()
senti_train['DCOILWTICO'] = dcoi_transformer.fit_transform(senti_train[['DCOILWTICO']])
senti_test['DCOILWTICO'] = dcoi_transformer.fit_transform(senti_test[['DCOILWTICO']])
# Out:
# C:\Users\Shiqi Wang\AppData\Local\Temp\ipykernel_11904\3387465992.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   senti_train['DCOILWTICO'] = dcoi_transformer.fit_transform(senti_train[['DCOILWTICO']])
# C:\Users\Shiqi Wang\AppData\Local\Temp\ipykernel_11904\3387465992.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   senti_test['DCOILWTICO'] = dcoi_transformer.fit_transform(senti_test[['DCOILWTICO']])

# %% [markdown]
# ### Set the time_step

# %%
senti_time_steps = 30

X_train_senti, y_train_senti = create_dataset_LSTM(senti_train, senti_train.DCOILWTICO, senti_time_steps)
X_test_senti, y_test_senti = create_dataset_LSTM(senti_test, senti_test.DCOILWTICO, senti_time_steps)
print(X_train_senti.shape, y_train_senti.shape)
# Out:
# (1521, 30, 2) (1521,)

# %% [markdown]
# ### Train the model with sentiment score as feature

# %%
model_senti = keras.Sequential()
model_senti.add(
  keras.layers.Bidirectional(
    keras.layers.LSTM(
      units=64, 
      input_shape=(X_train_senti.shape[1], X_train_senti.shape[2])
    )
  )
)

model_senti.add(keras.layers.Dropout(rate=0.2))
model_senti.add(keras.layers.Dense(units=1))
model_senti.compile(loss='mean_squared_error', optimizer='adam')

# %%
history_senti = model_senti.fit(
    X_train_senti, y_train_senti, 
    epochs=120, 
    batch_size=64, 
    validation_split=0.1,
    shuffle=False
)
# Out:
# Epoch 1/120
# 22/22 [==============================] - 3s 33ms/step - loss: 0.0979 - val_loss: 0.0063
# Epoch 2/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0109 - val_loss: 0.0035
# Epoch 3/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0105 - val_loss: 0.0024
# Epoch 4/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0097 - val_loss: 0.0019
# Epoch 5/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0087 - val_loss: 0.0024
# Epoch 6/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0082 - val_loss: 0.0021
# Epoch 7/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0093 - val_loss: 0.0019
# Epoch 8/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0103 - val_loss: 0.0016
# Epoch 9/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0080 - val_loss: 0.0015
# Epoch 10/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0066 - val_loss: 0.0014
# Epoch 11/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0065 - val_loss: 0.0013
# Epoch 12/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0055 - val_loss: 0.0013
# Epoch 13/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0062 - val_loss: 0.0014
# Epoch 14/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0072 - val_loss: 0.0011
# Epoch 15/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0070 - val_loss: 9.0803e-04
# Epoch 16/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 9.0843e-04
# Epoch 17/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 9.3449e-04
# Epoch 18/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0040 - val_loss: 8.8028e-04
# Epoch 19/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0042 - val_loss: 9.7414e-04
# Epoch 20/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0052 - val_loss: 0.0010
# Epoch 21/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0067 - val_loss: 7.2157e-04
# Epoch 22/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 7.9681e-04
# Epoch 23/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0039 - val_loss: 7.7566e-04
# Epoch 24/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0041 - val_loss: 8.3260e-04
# Epoch 25/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0037 - val_loss: 8.6466e-04
# Epoch 26/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0041 - val_loss: 0.0010
# Epoch 27/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 7.9987e-04
# Epoch 28/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0057 - val_loss: 7.1969e-04
# Epoch 29/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0039 - val_loss: 6.6814e-04
# Epoch 30/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0037 - val_loss: 0.0010
# Epoch 31/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 7.2969e-04
# Epoch 32/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0042 - val_loss: 0.0011
# Epoch 33/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0040 - val_loss: 7.5578e-04
# Epoch 34/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0054 - val_loss: 8.9108e-04
# Epoch 35/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0039 - val_loss: 7.1653e-04
# Epoch 36/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 9.6626e-04
# Epoch 37/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 6.7130e-04
# Epoch 38/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 9.5819e-04
# Epoch 39/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 7.1549e-04
# Epoch 40/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 9.0469e-04
# Epoch 41/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 6.7998e-04
# Epoch 42/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 8.7060e-04
# Epoch 43/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 6.6248e-04
# Epoch 44/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 8.7389e-04
# Epoch 45/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0035 - val_loss: 6.6976e-04
# Epoch 46/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 8.9759e-04
# Epoch 47/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 7.0455e-04
# Epoch 48/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 7.9917e-04
# Epoch 49/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 7.0029e-04
# Epoch 50/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0047 - val_loss: 6.7992e-04
# Epoch 51/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 5.8522e-04
# Epoch 52/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 6.9014e-04
# Epoch 53/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0031 - val_loss: 5.8662e-04
# Epoch 54/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 8.0227e-04
# Epoch 55/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0031 - val_loss: 6.5297e-04
# Epoch 56/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 6.9885e-04
# Epoch 57/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0034 - val_loss: 6.0014e-04
# Epoch 58/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0040 - val_loss: 6.2867e-04
# Epoch 59/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 5.8518e-04
# Epoch 60/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 7.0673e-04
# Epoch 61/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0035 - val_loss: 6.7655e-04
# Epoch 62/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0046 - val_loss: 5.8529e-04
# Epoch 63/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0040 - val_loss: 5.6413e-04
# Epoch 64/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 5.5729e-04
# Epoch 65/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 5.4596e-04
# Epoch 66/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 6.4500e-04
# Epoch 67/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0031 - val_loss: 5.6255e-04
# Epoch 68/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 6.6223e-04
# Epoch 69/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0035 - val_loss: 5.7001e-04
# Epoch 70/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0043 - val_loss: 5.6626e-04
# Epoch 71/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 5.2863e-04
# Epoch 72/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 5.7148e-04
# Epoch 73/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 5.2299e-04
# Epoch 74/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0034 - val_loss: 5.3932e-04
# Epoch 75/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0033 - val_loss: 5.2963e-04
# Epoch 76/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 6.5355e-04
# Epoch 77/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 5.8923e-04
# Epoch 78/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0035 - val_loss: 6.2048e-04
# Epoch 79/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 6.2614e-04
# Epoch 80/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 9.2839e-04
# Epoch 81/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 6.1459e-04
# Epoch 82/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 8.8197e-04
# Epoch 83/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0035 - val_loss: 6.3703e-04
# Epoch 84/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0047 - val_loss: 5.8808e-04
# Epoch 85/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0031 - val_loss: 5.9539e-04
# Epoch 86/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 7.6431e-04
# Epoch 87/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 5.7214e-04
# Epoch 88/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 8.5267e-04
# Epoch 89/120
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 6.2545e-04
# Epoch 90/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0040 - val_loss: 8.8335e-04
# Epoch 91/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0031 - val_loss: 7.4525e-04
# Epoch 92/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 8.5616e-04
# Epoch 93/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 5.4912e-04
# Epoch 94/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0040 - val_loss: 8.1041e-04
# Epoch 95/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0029 - val_loss: 5.7787e-04
# Epoch 96/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0044 - val_loss: 6.3094e-04
# Epoch 97/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 5.4507e-04
# Epoch 98/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 6.9824e-04
# Epoch 99/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0029 - val_loss: 5.0715e-04
# Epoch 100/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 7.1491e-04
# Epoch 101/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 5.1575e-04
# Epoch 102/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0037 - val_loss: 6.9685e-04
# Epoch 103/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 5.2814e-04
# Epoch 104/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0040 - val_loss: 6.3770e-04
# Epoch 105/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 4.8409e-04
# Epoch 106/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 6.0159e-04
# Epoch 107/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 4.8426e-04
# Epoch 108/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 4.9653e-04
# Epoch 109/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 4.7930e-04
# Epoch 110/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 5.3735e-04
# Epoch 111/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0031 - val_loss: 4.7673e-04
# Epoch 112/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 4.2114e-04
# Epoch 113/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 4.0503e-04
# Epoch 114/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 4.2717e-04
# Epoch 115/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0023 - val_loss: 4.0361e-04
# Epoch 116/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0025 - val_loss: 4.8046e-04
# Epoch 117/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 4.3774e-04
# Epoch 118/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 4.7131e-04
# Epoch 119/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 4.3079e-04
# Epoch 120/120
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0031 - val_loss: 4.0809e-04

# %%
plt.plot(history_senti.history['loss'], label='train_loss')
plt.plot(history_senti.history['val_loss'], label='validation_loss')
plt.legend()

# %% [markdown]
# ### Model Prediction

# %%
y_pred_senti = model_senti.predict(X_test_senti)

# Inverse normalisation of data
y_test_inv_senti = dcoi_transformer.inverse_transform(y_test_senti.reshape(1, -1))
y_pred_inv_senti = dcoi_transformer.inverse_transform(y_pred_senti)
# Out:
# 16/16 [==============================] - 0s 3ms/step

# %%
plt.plot(y_test_inv_senti.flatten(), marker='.', label="true")
plt.plot(y_pred_inv_senti.flatten(), 'r', label="prediction")
plt.ylabel('Crude Oil Price')
plt.xlabel('Time Step')
plt.legend()
plt.show()

# %%
MSE_senti = np.sum((y_test_inv_senti.flatten()-y_pred_inv_senti.flatten()) ** 2)/y_test_inv_senti.shape[1]
MSE_senti
# Out:
# 2.6589523590005015
