# %%
from selenium import webdriver
import time

# %%
# Function of crawler, pass in the pages range to use it
def news_headlines_crawler(page_start, page_end):
    
    headlines = []
    dates = []
    
    browser = webdriver.Chrome(r"chromedriver.exe")
    
    for page in range(page_start, page_end):
        # there are many pages of the news
        url = f"https://www.investing.com/commodities/crude-oil-news/{page}"
        
        # Using chrome driver to access the url
        browser.get(url)

        # Finding news headlines and their corresponding dates
        elements= browser.find_elements_by_xpath("//*[@class='title' or @class='date']")
        elems = elements.copy()

        raw_data = []
        for post in elems:
            raw_data.append(post.text)

        # Delete the first three empty values
        del raw_data[:3]

        # Delete the last four useless values
        del raw_data[-4:]

        i=0
        for item in raw_data:
            if item == '':
                continue
            
            # Odd numbered items are news headlines text
            if i== 0 :
                headlines.append(item)
                i+= 1
            # Even numbered items are date text
            else :
                dates.append(item[3:])
                # One page includes 10 groups of news headlines and corresponding dates
                if len(dates) % 10 == 0:
                    break
                i-= 1
        
    return (headlines, dates)

# %% [markdown]
# Set the 'start_page' and 'end_page' to define the period to crawl

# %%
import pandas as pd

start_page = 3
end_page = 4

# call the function 'news_headlines_crawler'
headlines_dates_tuple = news_headlines_crawler(start_page, end_page)

# construct the dictionary
dic = {'headlines' : headlines_dates_tuple[0], 'dates': headlines_dates_tuple[1]}

# construct the dataframe
df_news = pd.DataFrame(data=dic)
df_news
# Out:
#                                            headlines         dates
# 0  European Stocks Lower; German Industrial Outpu...  Sep 07, 2022
# 1  More trouble ahead for bruised Indian rupee - ...  Sep 07, 2022
# 2  European Stock Futures Lower; German Industria...  Sep 07, 2022
# 3  Oil Extends Losses as Demand Fears Outweigh OP...  Sep 06, 2022
# 4  Stocks fall, yields rise as investors weigh ra...  Sep 06, 2022
# 5  Oil Rolls Back Labor Day Gain, Loses More With...  Sep 06, 2022
# 6  U.S. Stocks Turn Lower to Start Week Ahead of ...  Sep 06, 2022
# 7  Crude Oil Mixed; Demand Destruction Fears Comp...  Sep 06, 2022
# 8  Dow Futures Rise 200 Pts; Services PMI Data in...  Sep 06, 2022
# 9  European Energy, ISM Non-Manufacturing, Yuan L...  Sep 06, 2022

# %%
# Store the data
df_news.to_excel('Oil_News_Title_Date.xlsx', index = False)
